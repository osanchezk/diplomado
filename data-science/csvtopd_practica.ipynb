# %% [markdown]
# # Intro python data science
# ## Práctica 08: importar datos csv a python
#
# Vamos a ver cómo importar csv cuando:
# * Punto 1: datos separados por coma
# * Punto 2: datos separados por puntos y comas
# * Punto 3: no hay nombres de columnas

# %% [markdown]
# # Punto 0:

# %%
# importar pandas
import pandas as pd

# %% [markdown]
# # Punto 1:

# %%
# caso 1: datos separados por coma

# %%
path = 'datos_rrss_t1.csv'
pd.read_csv(path, )
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009

# %% [markdown]
# # Punto 2:

# %%
# caso 2: datos separados por puntos y comas

# %%
path = 'datos_rrss_t2.csv'
pd.read_csv(path, sep=";")
# Out:
#       Nombre  Cantidad     ES_FBK  Anio
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010

# %% [markdown]
# # Punto 3:

# %%
# caso 3: no hay nombres de columnas

# %%
path = 'datos_rrss_t3.csv'
pd.read_csv(path, header=None, names=['Nombre', 'Cantidad', 'Val', 'Año'])
# Out:
#       Nombre  Cantidad        Val   Año
# 0   Facebook      2449  VERDADERO  2006
# 1    Twitter       339      FALSO  2006
# 2  Instagram      1000  VERDADERO  2010
# 3    YouTube      2000      FALSO  2005
# 4   LinkedIn       663      FALSO  2003
# 5   WhatsApp      1600  VERDADERO  2009

# %%
nginxLog = 'access.log.0'

# %%
df = pd.read_csv(nginxLog,
              sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
              engine='python',
              usecols=[0, 3, 4, 5, 6, 7, 8],
              names=['ip', 'time', 'request', 'status', 'size', 'referer', 'user_agent'],
              na_values='-',
              header=None
                )

# %% [markdown]
# # Gracias!
# ## Espero que te lleves algo útil de este notebook 😀
#
# Para más videos de programación para ciencia de datos
#
# https://www.youtube.com/c/RafaGonzalezGouveia/
#
# Si quieres realizar alguno de los cursos online de pago, ve a:
#
# https://cursos.gonzalezgouveia.com

# %%
df
# Out:
#                     ip                          time  \
# 0      136.158.118.198  [09/Dec/2021:06:25:05 +0000]
# 1         35.204.27.55  [09/Dec/2021:06:25:05 +0000]
# 2         35.204.27.55  [09/Dec/2021:06:25:06 +0000]
# 3         35.204.27.55  [09/Dec/2021:06:25:06 +0000]
# 4         35.204.27.55  [09/Dec/2021:06:25:06 +0000]
# ...                ...                           ...
# 19995     93.158.90.31  [09/Dec/2021:10:10:10 +0000]
# 19996      172.31.8.44  [09/Dec/2021:10:10:12 +0000]
# 19997     172.31.39.88  [09/Dec/2021:10:10:12 +0000]
# 19998     93.158.90.31  [09/Dec/2021:10:10:14 +0000]
# 19999   157.90.177.215  [09/Dec/2021:10:10:16 +0000]
#
#                                                  request  status    size  \
# 0      "GET /sites/default/files/styles/crop_16_9/pub...     200  105219
# 1                                       "GET / HTTP/1.1"     301     178
# 2                                       "GET / HTTP/1.1"     200   23398
# 3                                 "GET /mining HTTP/1.1"     301     178
# 4                                       "GET / HTTP/1.1"     301     178
# ...                                                  ...     ...     ...
# 19995            "GET /taxonomy/term/4946/feed HTTP/1.1"     200    3234
# 19996                                   "GET / HTTP/1.1"     400     264
# 19997                                   "GET / HTTP/1.1"     301     178
# 19998            "GET /taxonomy/term/2982/feed HTTP/1.1"     200    1609
# 19999  "GET /form/hashtag?url=https://mexicobusiness....     200    7182
#
#                          referer  \
# 0      "https://www.google.com/"
# 1                            "-"
# 2                            "-"
# 3                            "-"
# 4                            "-"
# ...                          ...
# 19995                        "-"
# 19996                        "-"
# 19997                        "-"
# 19998                        "-"
# 19999                        "-"
#
#                                               user_agent
# 0      "Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
# 1                                      "newspaper/0.2.8"
# 2                                      "newspaper/0.2.8"
# 3                                      "newspaper/0.2.8"
# 4                                      "newspaper/0.2.8"
# ...                                                  ...
# 19995  "Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
# 19996                            "ELB-HealthChecker/2.0"
# 19997                            "ELB-HealthChecker/2.0"
# 19998  "Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
# 19999  "Mozilla/5.0 (compatible; BLEXBot/1.0; +http:/...
#
# [20000 rows x 7 columns]
