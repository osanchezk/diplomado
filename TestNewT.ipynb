# %%
import pandas as pd

# %%
getData = pd.read_csv("data.csv")

# %%
getData.head(10)
# Out:
#           Date         Sector
# 0  09/Dec/2021         mining
# 1  09/Dec/2021  entrepreneurs
# 2  09/Dec/2021        finance
# 3  09/Dec/2021         health
# 4  09/Dec/2021           tech
# 5  09/Dec/2021     automotive
# 6  09/Dec/2021         health
# 7  09/Dec/2021      logistics
# 8  09/Dec/2021         energy
# 9  09/Dec/2021     automotive

# %%
getData[{"Sector"}]
# Out:
#                   Sector
# 0                 mining
# 1          entrepreneurs
# 2                finance
# 3                 health
# 4                   tech
# ...                  ...
# 132063      agribusiness
# 132064            health
# 132065            energy
# 132066  policyandeconomy
# 132067        automotive
#
# [132068 rows x 1 columns]

# %%
getData.describe()
# Out:
#                Date  Sector
# count        132068  132068
# unique            7      19
# top     07/Dec/2021  mining
# freq          28734   17653
