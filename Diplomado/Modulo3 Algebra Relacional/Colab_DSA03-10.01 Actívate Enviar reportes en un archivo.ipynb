# %% [markdown]
# <h2>Práctica Tema 3 </h2>
# <h3>Módulo 3 - Manipulación de Datos en Python </h3>

# %% [markdown]
# Si lograste terminar tu práctica del tema 2, toma el resultado, pero esta vez, mándalo a un archivo de Excel llamado salida.xlsx en una hoja llamada <b>gentePorPais</b>.

# %% [markdown]
# Puedes copiar tus archivos de la práctica 2 en esta carpeta

# %% [markdown]
# Si no terminaste tu práctica del tema 2, aún estas en un buen momento
