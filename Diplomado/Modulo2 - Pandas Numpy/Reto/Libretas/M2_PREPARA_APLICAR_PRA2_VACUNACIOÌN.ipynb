# %% [markdown]
# # **Módulo 2. Plataformas de Aplicación sobre Python**
# **Práctica 2 - Vacunación por país**
# ---

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Leer el archivo country_vaccinations.csv

# %%
vacunas = pd.read_csv('/content/country_vaccinations.csv')

# %%
vacunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              3081 non-null   object
#  1   iso_code                             2833 non-null   object
#  2   date                                 3081 non-null   object
#  3   total_vaccinations                   1980 non-null   float64
#  4   people_vaccinated                    1643 non-null   float64
#  5   people_fully_vaccinated              1016 non-null   float64
#  6   daily_vaccinations_raw               1642 non-null   float64
#  7   daily_vaccinations                   2960 non-null   float64
#  8   total_vaccinations_per_hundred       1980 non-null   float64
#  9   people_vaccinated_per_hundred        1643 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1016 non-null   float64
# ...

# %%
vacunas.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# La cantidad de vacunas (COMO LO REPORTA CADDA PAIS EN LA COLUMNA vaccines) aplicadas de cada compañia

# %%
vacunas[['vaccines', 'daily_vaccinations']].groupby('vaccines').sum()
# Out:
#                                                     daily_vaccinations
# vaccines
# Covaxin, Oxford/AstraZeneca                                  7536062.0
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                17048554.0
# Moderna, Pfizer/BioNTech                                    53312456.0
# Oxford/AstraZeneca                                            834755.0
# Oxford/AstraZeneca, Pfizer/BioNTech                         28254979.0
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/...           3950325.0
# Oxford/AstraZeneca, Sinopharm/Beijing                        1008119.0
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V               27232.0
# Oxford/AstraZeneca, Sinovac                                  4209095.0
# Oxford/AstraZeneca, Sputnik V                                  65000.0
# Pfizer/BioNTech                                              2468639.0
# Pfizer/BioNTech, Sinopharm/Beijing                            197807.0
# ...

# %% [markdown]
# La cantidad de vacunas aplicadas en todo el mundo

# %%
vacunas['daily_vaccinations'].sum()
# Out:
# 165073608.0

# %% [markdown]
# El promedio de vacunas DIARIAS aplicadas por país

# %%
vacunas[['country', 'daily_vaccinations']].groupby('country').mean()
# Out:
#                           daily_vaccinations
# country
# Albania                            44.625000
# Algeria                            30.000000
# Andorra                            51.750000
# Anguilla                          149.000000
# Argentina                       12705.630435
# ...                                      ...
# Turks and Caicos Islands          222.000000
# United Arab Emirates           101290.384615
# United Kingdom                 226934.098361
# United States                  820716.618182
# Wales                           10869.114754
#
# [90 rows x 1 columns]

# %% [markdown]
# La cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo

# %%
vacFec = vacunas.loc[vacunas['date']=='2021-01-29', ['country', 'daily_vaccinations']]
vacFec['daily_vaccinations'].sum()
# Out:
# 4634618.0

# %%
vacunas2 = pd.read_csv('/content/country_vaccinations.csv', parse_dates=['date'])
vacunas2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              3081 non-null   object
#  1   iso_code                             2833 non-null   object
#  2   date                                 3081 non-null   datetime64[ns]
#  3   total_vaccinations                   1980 non-null   float64
#  4   people_vaccinated                    1643 non-null   float64
#  5   people_fully_vaccinated              1016 non-null   float64
#  6   daily_vaccinations_raw               1642 non-null   float64
#  7   daily_vaccinations                   2960 non-null   float64
#  8   total_vaccinations_per_hundred       1980 non-null   float64
#  9   people_vaccinated_per_hundred        1643 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1016 non-null   float64
# ...

# %%
vacunas['date'] = pd.to_datetime(vacunas['date'])
vacunas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              3081 non-null   object
#  1   iso_code                             2833 non-null   object
#  2   date                                 3081 non-null   datetime64[ns]
#  3   total_vaccinations                   1980 non-null   float64
#  4   people_vaccinated                    1643 non-null   float64
#  5   people_fully_vaccinated              1016 non-null   float64
#  6   daily_vaccinations_raw               1642 non-null   float64
#  7   daily_vaccinations                   2960 non-null   float64
#  8   total_vaccinations_per_hundred       1980 non-null   float64
#  9   people_vaccinated_per_hundred        1643 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1016 non-null   float64
# ...

# %%
vacunas['date'].min()
# Out:
# Timestamp('2020-12-13 00:00:00')

# %%
vacunas['date'].max()
# Out:
# Timestamp('2021-02-13 00:00:00')

# %%
vacunas['date'].max() - vacunas['date'].min()
# Out:
# Timedelta('62 days 00:00:00')

# %%
vacunas['date'].dt.year
# Out:
# 0       2021
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 3076    2021
# 3077    2021
# 3078    2021
# 3079    2021
# 3080    2021
# Name: date, Length: 3081, dtype: int64

# %%
vacunas[vacunas['date']<'2020-12-20']
# Out:
#                country iso_code       date  total_vaccinations  \
# 406             Canada      CAN 2020-12-19                 NaN
# 543              China      CHN 2020-12-15           1500000.0
# 544              China      CHN 2020-12-16                 NaN
# 545              China      CHN 2020-12-17                 NaN
# 546              China      CHN 2020-12-18                 NaN
# 547              China      CHN 2020-12-19                 NaN
# 847            England      NaN 2020-12-13             55389.0
# 848            England      NaN 2020-12-14                 NaN
# 849            England      NaN 2020-12-15                 NaN
# 850            England      NaN 2020-12-16                 NaN
# 851            England      NaN 2020-12-17                 NaN
# 852            England      NaN 2020-12-18                 NaN
# 853            England      NaN 2020-12-19                 NaN
# 1432            Israel      ISR 2020-12-19                58.0
# ...

# %% [markdown]
# Una columna derivada con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_row

# %%
vacunas['diferencia'] = vacunas['daily_vaccinations_raw'] - vacunas['daily_vaccinations']
vacunas
# Out:
#       country iso_code       date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB 2021-01-10                 0.0                0.0
# 1     Albania      ALB 2021-01-11                 NaN                NaN
# 2     Albania      ALB 2021-01-12               128.0              128.0
# 3     Albania      ALB 2021-01-13               188.0              188.0
# 4     Albania      ALB 2021-01-14               266.0              266.0
# ...       ...      ...        ...                 ...                ...
# 3076    Wales      NaN 2021-02-08            632251.0           628760.0
# 3077    Wales      NaN 2021-02-09            659106.0           655419.0
# 3078    Wales      NaN 2021-02-10            687892.0           684097.0
# 3079    Wales      NaN 2021-02-11            719954.0           715944.0
# 3080    Wales      NaN 2021-02-12            753669.0           749445.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# La diferencia de vacunación entre los días 20/01/21 y 31/01/21 para México y EEUU

# %%
MexEU = vacunas[['country', 'date', 'daily_vaccinations']]
MexEU = MexEU.query('(country=="Mexico" | country=="United States") & (date=="2021-01-20" | date=="2021-01-31")')

MexEU
#print('Diferencia para México: ', MexEU.iloc[0][2]-MexEU.iloc[1][2])
#print('Diferencia para EEUU: ', MexEU.iloc[2][2]-MexEU.iloc[3][2])
# Out:
#             country       date  daily_vaccinations
# 1800         Mexico 2021-01-20             44066.0
# 1811         Mexico 2021-01-31              6243.0
# 2994  United States 2021-01-20            892403.0
# 3005  United States 2021-01-31           1324949.0

# %%
print('Diferencia para México: ', MexEU.iloc[0][2]-MexEU.iloc[1][2])
print('Diferencia para EEUU: ', MexEU.iloc[2][2]-MexEU.iloc[3][2])
# Out:
# Diferencia para México:  37823.0
# Diferencia para EEUU:  -432546.0

# %% [markdown]
# Guardar todos los dataframe usados en formato de archivo de Excel

# %%
#ExcelWriter
vacunas.to_excel('/content/datos.xlsx', sheet_name='datos1')
MexEU.to_excel('')

# %%
# PARA EL RETO
# investigar la función where
# o utilizar un list comprehenssion
