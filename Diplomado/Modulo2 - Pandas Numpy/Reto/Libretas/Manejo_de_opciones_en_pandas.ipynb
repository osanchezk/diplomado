# %% [markdown]
# Dataframe de ejemplo

# %%
import pandas as pd
vacunas = pd.read_csv('/content/country_vaccinations.csv')
vacunas
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# 2     Albania      ALB  2021-01-12               128.0              128.0
# 3     Albania      ALB  2021-01-13               188.0              188.0
# 4     Albania      ALB  2021-01-14               266.0              266.0
# ...       ...      ...         ...                 ...                ...
# 3076    Wales      NaN  2021-02-08            632251.0           628760.0
# 3077    Wales      NaN  2021-02-09            659106.0           655419.0
# 3078    Wales      NaN  2021-02-10            687892.0           684097.0
# 3079    Wales      NaN  2021-02-11            719954.0           715944.0
# 3080    Wales      NaN  2021-02-12            753669.0           749445.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# Modificar la cantidad de filas mostradas

# %%
pd.options.display.max_rows = 5

# %%
vacunas
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Albania      ALB  2021-01-10                 0.0                0.0
# 1     Albania      ALB  2021-01-11                 NaN                NaN
# ...       ...      ...         ...                 ...                ...
# 3079    Wales      NaN  2021-02-11            719954.0           715944.0
# 3080    Wales      NaN  2021-02-12            753669.0           749445.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                         NaN                     NaN                 NaN
# 1                         NaN                     NaN                64.0
# ...                       ...                     ...                 ...
# 3079                   4010.0                 32062.0             27897.0
# 3080                   4224.0                 33715.0             27743.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# Cambiar el manejo de la cantidad de decimales

# %%
import pandas as pd
ventas = pd.DataFrame(
{"Estado": ["Monterrye", "Ciudad de México", "Hidalgo", "Guerrero"],
 "Ventas": [1500, 2000, 1200, 800]
})
ventas['porcentaje'] = ventas['Ventas'] *100 / ventas['Ventas'].sum()
ventas
# Out:
#              Estado  Ventas  porcentaje
# 0         Monterrye    1500   27.272727
# 1  Ciudad de México    2000   36.363636
# 2           Hidalgo    1200   21.818182
# 3          Guerrero     800   14.545455

# %%
pd.set_option("display.precision", 2)

# %%
ventas
# Out:
#              Estado  Ventas  porcentaje
# 0         Monterrye    1500       27.27
# 1  Ciudad de México    2000       36.36
# 2           Hidalgo    1200       21.82
# 3          Guerrero     800       14.55
